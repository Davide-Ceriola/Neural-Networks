# %% [markdown]
# Codici per configurazioni e commit

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Github/

# %%
username = 'Davide-Ceriola'
repository = 'Neural-Networks'
git_token = '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'

# !git clone https://{git_token}@github.com/{username}/{repository}

# %cd {repository}

# %%
# %ls -a

# %%
# !git status

# %%
# !git add .

# %%
# !git config --global user.email "ceriola.1850563@studenti.uniroma1.it"
# !git config --global user.name "Davide-Ceriola"

# %%
# !git commit -m "first commit"

# %%
# !git push

# %% [markdown]
# Codici per training

# %%
from IPython.display import clear_output

# %%
# !wget -O EMO-DB.zip http://emodb.bilderbar.info/download/download.zip
# Out:
# --2022-10-21 14:19:34--  http://emodb.bilderbar.info/download/download.zip
# Resolving emodb.bilderbar.info (emodb.bilderbar.info)... 85.13.147.80
# Connecting to emodb.bilderbar.info (emodb.bilderbar.info)|85.13.147.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40567066 (39M) [application/zip]
# Saving to: ‘EMO-DB.zip’
#
# EMO-DB.zip          100%[===================>]  38.69M  4.02MB/s    in 9.8s
#
# 2022-10-21 14:19:44 (3.95 MB/s) - ‘EMO-DB.zip’ saved [40567066/40567066]

# %%
# !mv /content/drive/MyDrive/Github/Neural-Networks/EMO-DB.zip /content/drive/MyDrive/Github/Neural-Networks/data
# !unzip /content/drive/MyDrive/Github/Neural-Networks/data/EMO-DB.zip -d /content/drive/MyDrive/Github/Neural-Networks/data/EMO-DB

clear_output()

# %%
import os

os.chdir("/content/drive/MyDrive/Github/Neural-Networks")

# %%
# !python train.py -dn "EMO-DB" -id 3 -at "all" -ln "focal" -v 1 -it "mfcc" -c "disk" -m false
